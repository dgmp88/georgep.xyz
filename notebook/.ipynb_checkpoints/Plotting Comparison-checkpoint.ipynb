# %% [markdown]
# # Comparison of plotly, bokeh and matplotlib
#
# ## Installation
#
# Installation of matplotlib and plotly are very easy with pip or conda:
#
# ```
# [conda/pip] install [matplotlib/plotly]
# ```
#
# Installation of bokeh is a little more involved as it needs an extension to work with jupyter lab
#
# ```
# conda install bokeh
# ???jupyterlabextension install jupyter_bokeh???
# ```

# %% [markdown]
# ## Data creation
#
# Make some nice sine waves

# %%
import numpy as np

# Linearly spaced, 0 - 2 * pi
x = np.linspace(0, np.pi*2, 1000)

# Generate offset sine waves
data = [('offset %1.2f' % i, np.sin(x+i)) for i in np.linspace(0, np.pi, 10)]
legend, ys = zip(*data)

# %% [markdown]
# # Line Plots

# %% [markdown]
# ## Matplotlib

# %%
# Required to make it plot inline in matlab
# %matplotlib inline

import matplotlib.pyplot as plt

plt.figure(figsize=(10, 7))

for y in ys:
    plt.plot(x, y)
_ = plt.legend(legend)

# %% [markdown]
# ## Plotly

# %%
import plotly.graph_objs as go
import plotly.offline as py

traces = []
for leg, y in zip(legend, ys):
    traces.append(go.Scatter(x=x, y=y, name=leg))

py.iplot(traces)

# %% [markdown]
# ## Bokeh

# %%
from bokeh.plotting import figure, output_notebook, show, output_file

output_notebook()

# output_file('temp.html')
p = figure()

for leg, y in zip(legend, ys):
    p.line(x, y, legend=leg)

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="2399">Loading BokehJS ...</span>
#     </div>
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
# BokehUserWarning: ColumnDataSource's columns must be of the same length. Current lengths: ('x', 10000), ('y', 1000)
#   <div class="bk-root" id="10311e72-dc44-4820-8b66-a1c7c94f584f"></div>

# %% [markdown]
# # Scatter Plots

# %%
x, y = np.random.rand(2, 100)

# %% [markdown]
# # Matplotlib

# %%
plt.scatter(x, y)

# %% [markdown]
# # Plotly

# %%
traces = [go.Scatter(x=x, y=y, name=leg, mode='markers')]

py.iplot(traces)

# %% [markdown]
# # Bokeh

# %%
p = figure()
p.scatter(x, y)

show(p)
# Out:
#   <div class="bk-root" id="6c064dc2-6974-4c90-be9e-da353caf4680"></div>

# %% [markdown]
# # Histogram

# %%
x = np.random.normal(size=10000)

# %%
plt.figure(figsize=(10, 7))

plt.hist(x)
# Out:
# (array([  12.,   94.,  516., 1482., 2633., 2745., 1725.,  633.,  141.,
#           19.]),
#  array([-3.76250322, -3.02650303, -2.29050285, -1.55450266, -0.81850248,
#         -0.08250229,  0.6534979 ,  1.38949808,  2.12549827,  2.86149846,
#          3.59749864]),
#  <a list of 10 Patch objects>)

# %%
traces = [go.Histogram(x=x)]

py.iplot(traces)

# %% [markdown]
# ### Bokeh

# %%
output_notebook()

hist, edges = np.histogram(x, density=True, bins=100)

xx = np.linspace(-2, 2, 1000)

p = figure()
p.quad(top=hist, bottom=0, left=edges[:-1], right=edges[1:])

show(p)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="3426">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="05a78026-2be6-402c-bd29-1262b7985520"></div>
