# %%
import plotly.express as px
import numpy as np
import pandas as pd

# %%
from scipy.stats import skewnorm


data = []
for skew in range(-10, 10 + 1):
    x = skewnorm.rvs(skew, size=10000)
    counts, bins = np.histogram(x, bins=np.arange(-5, 5, 0.1))
    bins = bins[:-1]
    
    r = pd.DataFrame(dict(counts=counts, bins=bins))
    r['skew'] = skew
    data.append(r)
    
data = pd.concat(data, axis=0)

fig = px.bar(data, x='bins', y='counts', animation_frame='skew', range_x=[-5, 5], range_y=[0, data.counts.max()])

with open('tmp.html', 'w') as f:
    f.write(fig.to_html())

# %%
data
# Out:
#     counts  bins  skew
# 0        2  -5.0   -10
# 1       28  -4.0   -10
# 2      426  -3.0   -10
# 3     2674  -2.0   -10
# 4     6566  -1.0   -10
# 5      304   0.0   -10
# 6        0   1.0   -10
# 7        0   2.0   -10
# 8        0   3.0   -10
# 9        0   4.0   -10
# 0        0  -5.0    -9
# 1       24  -4.0    -9
# 2      424  -3.0    -9
# 3     2743  -2.0    -9
# 4     6458  -1.0    -9
# 5      351   0.0    -9
# 6        0   1.0    -9
# 7        0   2.0    -9
# 8        0   3.0    -9
# 9        0   4.0    -9
# 0        1  -5.0    -8
# 1       31  -4.0    -8
# 2      422  -3.0    -8
# 3     2755  -2.0    -8
# 4     6350  -1.0    -8
# 5      441   0.0    -8
# 6        0   1.0    -8
# 7        0   2.0    -8
# 8        0   3.0    -8
# 9        0   4.0    -8
# ..     ...   ...   ...
# 0        0  -5.0     7
# 1        0  -4.0     7
# 2        0  -3.0     7
# 3        0  -2.0     7
# 4      450  -1.0     7
# 5     6456   0.0     7
# 6     2648   1.0     7
# 7      420   2.0     7
# ...
